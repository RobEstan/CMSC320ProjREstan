# %% [markdown]
# ## **In Financial Terms, is going out-of-state for college worth the extra burden?**
# By Robert Estan

# %% [markdown]
# ## 1. Introduction
# Picking a college is an extremely important part of many young highschool graduates lives and for many out of state options seem very like the perfect oppurtunity to actualize your own potential to some and an intimading financial death sentence to others. The value of a college cannot be measured in it's totality by just financial statistics but hopefully this tutorial will provide an answer to the financial side of the question. This study is being done from the perspective of a highschool graduate in Maryland looking to major in CS.

# %% [markdown]
# ## 2. Data Curation
#
# We will be very optimistic in our data analysis here and assume our theoretical prospective student has been accept to all 20 of the Universities with the best CS programs in the US. We will take our definition of the best univiersites from usnews.com's ranking of them which can be found here: https://www.usnews.com/best-graduate-schools/top-science-schools/computer-science-rankings

# %% [markdown]
# ### 2.1 Tuition Data
# For our first piece of data we will be making a dataset containing the in state and out of state tuitions for every college within our top 20 list of colleges. Some Ivy-League Universities don't distinguish between in-state residents and out of state residents thus we will keep the per-year tuition the same for both categories for those Universities.

# %% [markdown]
# We will be entering our data into a custom csv file we made from the USNews ranking website as seen in the source column and read that csv into a dataframe.

# %%
import pandas as pd

file1 = "tuition.csv"
tuitions = pd.read_csv(file1)

tuitions
# Out:
#                                   university  in-state  out-of-state  \
# 0                 Carnegie Mellon University     63829         63829
# 1      Massachusetts Institute of Technology     60156         60156
# 2                        Stanford University     62484         62484
# 3         University of California--Berkeley     15891         48465
# 4   University of Illinois--Urbana-Champaign     17572         36068
# 5                         Cornell University     66014         66014
# 6            Georgia Institute of Technology     11764         32876
# 7                University of Texas--Austin     11698         41070
# 8                   University of Washington     12643         41997
# 9                       Princeton University     59710         59710
# 10         University of Michigan--Ann Arbor     17786         57273
# 11                       Columbia University     65524         65524
# 12        California Institute of Technology     63255         63255
# 13     University of California--Los Angeles     13752         46326
# 14       University of California--San Diego     16056         48630
# 15          University of Wisconsin--Madison     11205         40603
# 16                        Harvard University     59076         59076
# 17      University of Maryland--College Park     11505         40306
# 18         Purdue University--West Lafayette      9992         28794
# 19                University of Pennsylvania     66104         66104
#
#                                                source
# 0   https://www.usnews.com/best-colleges/carnegie-...
# 1   https://www.usnews.com/best-colleges/massachus...
# 2   https://www.usnews.com/best-colleges/stanford-...
# 3   https://www.usnews.com/best-colleges/universit...
# 4   https://www.usnews.com/best-colleges/universit...
# 5   https://www.usnews.com/best-colleges/cornell-u...
# 6   https://www.usnews.com/best-colleges/georgia-i...
# 7   https://www.usnews.com/best-colleges/universit...
# 8   https://www.usnews.com/best-colleges/universit...
# 9   https://www.usnews.com/best-colleges/princeton...
# 10  https://www.usnews.com/best-colleges/universit...
# 11  https://www.usnews.com/best-colleges/columbia-...
# 12  https://www.usnews.com/best-colleges/californi...
# 13  https://www.usnews.com/best-colleges/ucla-1315...
# 14  https://www.usnews.com/best-colleges/universit...
# 15  https://www.usnews.com/best-colleges/universit...
# 16  https://www.usnews.com/best-colleges/harvard-u...
# 17  https://www.usnews.com/best-colleges/universit...
# 18  https://www.usnews.com/best-colleges/purdue-un...
# 19  https://www.usnews.com/best-colleges/universit...

# %% [markdown]
# ### 2.2 Graduating Salary Data
# Here we have data about the graduating salary someone will get when leaving one of our top 20 colleges. This data mentions the median graduating salary of someone immediatily after college (we call that "starting"), the median salary of someone midway through their career (10 years after college) and the percentiles of salaries for graduates midway through their career. All of this data can be found through this link here: https://www.wsj.com/public/resources/documents/info-Salaries_for_Colleges_by_Type-sort.html

# %% [markdown]
# We will be creating a csv file to read as a dataframe in pandas. We will then be copying and pasta the data from the .html link because it simplfies the process of making the csv file rather than going through the loops of making specifically the table in the html page readable as a dataframe and then cutting only selecting the univerisities we care about from that dataframe.

# %%
file2 = "graduate_sals.csv"
salaries = pd.read_csv(file2)

salaries
# Out:
#                                   university  Starting  Mid-Career  \
# 0                 Carnegie Mellon University     61800      111000
# 1      Massachusetts Institute of Technology     72200      126000
# 2                        Stanford University     95200      122900
# 3         University of California--Berkeley     59900      112000
# 4   University of Illinois--Urbana-Champaign     52900       96100
# 5                         Cornell University     60300      110000
# 6            Georgia Institute of Technology     58300      106000
# 7                University of Texas--Austin     49700       93900
# 8                   University of Washington     48800       85300
# 9                       Princeton University     66500      131000
# 10         University of Michigan--Ann Arbor     52700       93000
# 11                       Columbia University     59400      107000
# 12        California Institute of Technology     75500      123000
# 13     University of California--Los Angeles     52600      101000
# 14       University of California--San Diego     51000      101000
# 15          University of Wisconsin--Madison     48900       87800
# 16                        Harvard University     63400      124000
# 17      University of Maryland--College Park     52000       95000
# 18         Purdue University--West Lafayette     51400       90500
# 19                University of Pennsylvania     60900      120000
#
#     10th-Percentile  25th-Percentile  75th-Percentile  90th-Percentile
# 0           63300.0          80100.0           150000         209000.0
# 1           76800.0          99200.0           168000         220000.0
# 2               NaN              NaN           126400              NaN
# 3           59500.0          81000.0           149000         201000.0
# 4           48200.0          68900.0           132000         177000.0
# 5           56800.0          79800.0           160000         210000.0
# 6           67200.0          85200.0           137000         183000.0
# 7           50100.0          67400.0           129000         188000.0
# 8           47000.0          59800.0           115000         149000.0
# 9           68900.0         100000.0           190000         261000.0
# 10          50900.0          69400.0           128000         182000.0
# 11          50300.0          71900.0           161000         241000.0
# 12              NaN         104000.0           161000              NaN
# 13          51300.0          72500.0           139000         193000.0
# 14          51700.0          75400.0           131000         177000.0
# 15          47400.0          62400.0           118000         170000.0
# 16          54800.0          86200.0           179000         288000.0
# 17          50400.0          68300.0           126000         166000.0
# 18          49900.0          67400.0           121000         168000.0
# 19          55900.0          79200.0           192000         282000.0

# %% [markdown]
# But we have a problem, we don't have data for some of the tables in this dataframe so we are going to have to do some imputation to fill in the missing values.

# %% [markdown]
# We will be going with median imputation for this dataset since mode imputation is usually used when there are recurring common values in the dataset (which there aren't in our case), hot imputation would have us take values from another college's data which seems counter productive and dangerous and cold imputation would have us take the value from another dataset recording the same thing our dataset is which isn't available at the moment. We could use mean imputation but that's more a matter of personal preference and we would have to round our values down into integers if we used means.

# %%
import numpy as np

#here we get the medians of all the columns with missing values
med_10 = salaries['10th-Percentile'].median()
med_25 = salaries['25th-Percentile'].median()
med_90 = salaries['90th-Percentile'].median()

#here we fill in our missing values with our medians
salaries['10th-Percentile'] = salaries['10th-Percentile'].fillna(med_10)
salaries['25th-Percentile'] = salaries['25th-Percentile'].fillna(med_25)
salaries['90th-Percentile'] = salaries['90th-Percentile'].fillna(med_90)

salaries
# Out:
#                                   university  Starting  Mid-Career  \
# 0                 Carnegie Mellon University     61800      111000
# 1      Massachusetts Institute of Technology     72200      126000
# 2                        Stanford University     95200      122900
# 3         University of California--Berkeley     59900      112000
# 4   University of Illinois--Urbana-Champaign     52900       96100
# 5                         Cornell University     60300      110000
# 6            Georgia Institute of Technology     58300      106000
# 7                University of Texas--Austin     49700       93900
# 8                   University of Washington     48800       85300
# 9                       Princeton University     66500      131000
# 10         University of Michigan--Ann Arbor     52700       93000
# 11                       Columbia University     59400      107000
# 12        California Institute of Technology     75500      123000
# 13     University of California--Los Angeles     52600      101000
# 14       University of California--San Diego     51000      101000
# 15          University of Wisconsin--Madison     48900       87800
# 16                        Harvard University     63400      124000
# 17      University of Maryland--College Park     52000       95000
# 18         Purdue University--West Lafayette     51400       90500
# 19                University of Pennsylvania     60900      120000
#
#     10th-Percentile  25th-Percentile  75th-Percentile  90th-Percentile
# 0           63300.0          80100.0           150000         209000.0
# 1           76800.0          99200.0           168000         220000.0
# 2           51500.0          75400.0           126400         190500.0
# 3           59500.0          81000.0           149000         201000.0
# 4           48200.0          68900.0           132000         177000.0
# 5           56800.0          79800.0           160000         210000.0
# 6           67200.0          85200.0           137000         183000.0
# 7           50100.0          67400.0           129000         188000.0
# 8           47000.0          59800.0           115000         149000.0
# 9           68900.0         100000.0           190000         261000.0
# 10          50900.0          69400.0           128000         182000.0
# 11          50300.0          71900.0           161000         241000.0
# 12          51500.0         104000.0           161000         190500.0
# 13          51300.0          72500.0           139000         193000.0
# 14          51700.0          75400.0           131000         177000.0
# 15          47400.0          62400.0           118000         170000.0
# 16          54800.0          86200.0           179000         288000.0
# 17          50400.0          68300.0           126000         166000.0
# 18          49900.0          67400.0           121000         168000.0
# 19          55900.0          79200.0           192000         282000.0

# %% [markdown]
# And voila some well populated datasets ready to be explored.

# %% [markdown]
# ### 2.3 Merging our datasets
# The astute readers among you will have noticied that our two datasets have two columns that are exactly the same. That's right the univeristy name column. To simplfy our work and centralize our data we can merge our datasets using this name column as our basis for merging.

# %%
proj_data = pd.merge(tuitions, salaries, on="university",how="inner")

proj_data
# Out:
#                                   university  in-state  out-of-state  \
# 0                 Carnegie Mellon University     63829         63829
# 1      Massachusetts Institute of Technology     60156         60156
# 2                        Stanford University     62484         62484
# 3         University of California--Berkeley     15891         48465
# 4   University of Illinois--Urbana-Champaign     17572         36068
# 5                         Cornell University     66014         66014
# 6            Georgia Institute of Technology     11764         32876
# 7                University of Texas--Austin     11698         41070
# 8                   University of Washington     12643         41997
# 9                       Princeton University     59710         59710
# 10         University of Michigan--Ann Arbor     17786         57273
# 11                       Columbia University     65524         65524
# 12        California Institute of Technology     63255         63255
# 13     University of California--Los Angeles     13752         46326
# 14       University of California--San Diego     16056         48630
# 15          University of Wisconsin--Madison     11205         40603
# 16                        Harvard University     59076         59076
# 17      University of Maryland--College Park     11505         40306
# 18         Purdue University--West Lafayette      9992         28794
# 19                University of Pennsylvania     66104         66104
#
#                                                source  Starting  Mid-Career  \
# 0   https://www.usnews.com/best-colleges/carnegie-...     61800      111000
# 1   https://www.usnews.com/best-colleges/massachus...     72200      126000
# 2   https://www.usnews.com/best-colleges/stanford-...     95200      122900
# 3   https://www.usnews.com/best-colleges/universit...     59900      112000
# 4   https://www.usnews.com/best-colleges/universit...     52900       96100
# 5   https://www.usnews.com/best-colleges/cornell-u...     60300      110000
# 6   https://www.usnews.com/best-colleges/georgia-i...     58300      106000
# 7   https://www.usnews.com/best-colleges/universit...     49700       93900
# 8   https://www.usnews.com/best-colleges/universit...     48800       85300
# 9   https://www.usnews.com/best-colleges/princeton...     66500      131000
# 10  https://www.usnews.com/best-colleges/universit...     52700       93000
# 11  https://www.usnews.com/best-colleges/columbia-...     59400      107000
# 12  https://www.usnews.com/best-colleges/californi...     75500      123000
# 13  https://www.usnews.com/best-colleges/ucla-1315...     52600      101000
# 14  https://www.usnews.com/best-colleges/universit...     51000      101000
# 15  https://www.usnews.com/best-colleges/universit...     48900       87800
# 16  https://www.usnews.com/best-colleges/harvard-u...     63400      124000
# 17  https://www.usnews.com/best-colleges/universit...     52000       95000
# 18  https://www.usnews.com/best-colleges/purdue-un...     51400       90500
# 19  https://www.usnews.com/best-colleges/universit...     60900      120000
#
#     10th-Percentile  25th-Percentile  75th-Percentile  90th-Percentile
# 0           63300.0          80100.0           150000         209000.0
# 1           76800.0          99200.0           168000         220000.0
# 2           51500.0          75400.0           126400         190500.0
# 3           59500.0          81000.0           149000         201000.0
# 4           48200.0          68900.0           132000         177000.0
# 5           56800.0          79800.0           160000         210000.0
# 6           67200.0          85200.0           137000         183000.0
# 7           50100.0          67400.0           129000         188000.0
# 8           47000.0          59800.0           115000         149000.0
# 9           68900.0         100000.0           190000         261000.0
# 10          50900.0          69400.0           128000         182000.0
# 11          50300.0          71900.0           161000         241000.0
# 12          51500.0         104000.0           161000         190500.0
# 13          51300.0          72500.0           139000         193000.0
# 14          51700.0          75400.0           131000         177000.0
# 15          47400.0          62400.0           118000         170000.0
# 16          54800.0          86200.0           179000         288000.0
# 17          50400.0          68300.0           126000         166000.0
# 18          49900.0          67400.0           121000         168000.0
# 19          55900.0          79200.0           192000         282000.0

# %% [markdown]
# And now we are completely done with our data cleaning portion and ready to move onto analysis

# %% [markdown]
# ##3. Exploratory Data Analysis

# %% [markdown]
# Time to make some plots! For this section we will be making three plots to understand certain trends in our data.

# %% [markdown]
# ### 3.1
# Our first plot will be examing the differences between Unviersities' in-state and out-of-state tuitions using a regular scatter plot.

# %%
import matplotlib
import matplotlib.pyplot as plt

#setting adjustment which is mainly visual and optional for you
matplotlib.rcParams['figure.figsize'] = [11, 11]

#a function to help us make more scatter plots in the future
def scatter_func(our_frame, x_col, y_col):
    our_frame.plot(kind="scatter", x=x_col, y=y_col, title=x_col + " vs " + y_col, color="green")
    plt.show()

# plotting student populations vs faculty count
scatter_func(proj_data, "in-state", "out-of-state")

# %% [markdown]
# As we can see here there is a deep and large divide for college tuitions between the colleges whose tuitions cost roughly more than 60k and the colleges whose out-of-state tuitions don't even cost that much. The isolated group of colleges to the top right should be ivy-leage colleges since they have large prices that don't change for state residency while the colleges closer to the left are more likely to be public colleges that have state incentive to discourage out-of-state students from applying with higher tuitions.

# %% [markdown]
# ### 3.2
# Our second type of plot will be bar plots

# %%
#size adjustment again
matplotlib.rcParams['figure.figsize'] = [10, 7]

#a function to help us make more bar plots in the future
def bar_func(our_frame, x_col, nam):
    our_frame.set_index(x_col, inplace=True)
    our_frame.plot(kind="bar", title="Bar plot for " + nam + " salaries")
    plt.show()

# plotting starting salary vs mid-career salary
bar_func(proj_data[["university", "Starting", "Mid-Career"]], "university", "Post-Grad")


matplotlib.rcParams['figure.figsize'] = [14, 7]
#plotting midcareer salary variation
bar_func(proj_data[["university",  "10th-Percentile", "25th-Percentile", "Mid-Career", "75th-Percentile", "90th-Percentile"]], "university", "Mid-Career")

# %% [markdown]
# From these results we can see how large of a variance there is between salaries from post-graduates midway through their career and especially in the 75th percentile and 90th percentiles there are huge jumps in salary. For the first barplot we can see how there is a pretty consistently large gap in salary from the beginning of a career right out of college and halfway through it.

# %% [markdown]
# ### 3.3
# Our final new plot method will cover histograms for the data

# %%
#size adjustment again
matplotlib.rcParams['figure.figsize'] = [13, 9]

#a function to help us make more histogram plots in the future
def hist_func(our_frame, x_col, nam):
    our_frame.plot(kind="hist", title="Histogram for " + nam + " salaries", xlabel=x_col)
    plt.show()

# plotting Starting Salary compared to Mid-Career Salaray
hist_func(proj_data[["Starting", "Mid-Career"]], "Salaries", "Post-Grad")
hist_func(proj_data[["10th-Percentile", "25th-Percentile", "Mid-Career", "75th-Percentile", "90th-Percentile"]], "Salaries", "Post-Grad")

# %% [markdown]
# As we can see here the distance in salary earned between immediate post-grad salary and midway salary is much more clearly expressed in the top histogram. The bottom histogram shows the consistent increase in salary size as you move from the 10th, 25th 50th, 75th to 90th percentile and at the end we can see how the 90th percentile of Midway career salaries has a much large range of values than the previous percentiles.

# %% [markdown]
# ## 4. Primary Analysis and Visualization

# %% [markdown]
# Now we will use some machine learning to form a linear regression model to give us the final visualization of our data that we need to come to a conclusion on the subject matter.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import numpy as np

X = proj_data[["out-of-state"]]

y = proj_data['Mid-Career']

poly = PolynomialFeatures(degree=2)
poly_X = poly.fit_transform(X)

poly_model = LinearRegression()
poly_model.fit(poly_X,y)

coefs = poly_model.coef_
tuits = np.linspace(0, 70000, 20).reshape(-1, 1)
poly_tuition = poly.fit_transform(tuits)
predictions = poly_model.predict(poly_tuition)

plt.plot(tuits, predictions, color="red", x="Out of State Tuition", y="Salary in 10 Years")
plt.scatter(y=proj_data[['Mid-Career']], x=proj_data[['out-of-state']])

# %% [markdown]
# ## 5. Insights and Conclusion

# %% [markdown]
# From all of our plots and data analysis one can come to a pretty clear conclusion that going to an out-of-state college is worth it despite the increased cost in tuition. Our linear regression model above shows a moderately strong correlation between the out of state tuition cost of a university and the eventually salary of that person halfway through their career. While it is still up to personal choice and some may not want to deal with the debt right after leaving colleges, it is statistically sound to say that the increase in salary outweighes the cost of tuition with enough time.
